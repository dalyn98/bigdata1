# %%
import pandas as pd
import numpy as np
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %%
data = pd.read_csv('train.csv',  encoding='CP949')
data.head()
# Out:
#    custid  gender     총구매액  구매건수  평균구매가격  평균할부개월수  구매브랜드종류  내점일수  수입상품_구매비율  \
# 0      18       0   680100    15   45340      1.7        9    10       26.7
# 1      21       0   353450     9   39272      1.2        6     8       11.1
# 2      23       0  5671400    36  157539      2.8       22    16        5.6
# 3      26       0  1964000    28   70143      1.4       15    14       39.3
# 4      35       0   885000     5  177000      6.0        5     2        0.0
#
#    주말방문비율  가을_구매건수  겨울_구매건수  봄_구매건수  여름_구매건수  아침_구매건수  저녁_구매건수  점심_구매건수 주구매코너
# 0   100.0      NaN      9.0     6.0      NaN      NaN      6.0      9.0   화장품
# 1    37.5      NaN      5.0     4.0      NaN      3.0      NaN      6.0  영캐주얼
# 2    37.5      7.0     17.0    12.0      NaN     10.0     11.0     15.0   장신구
# 3    28.6      5.0      8.0    15.0      NaN      NaN     18.0     10.0   화장품
# 4   100.0      NaN      NaN     5.0      NaN      NaN      5.0      NaN   피혁A

# %%
data.dtypes
# Out:
# custid         int64
# gender         int64
# 총구매액           int64
# 구매건수           int64
# 평균구매가격         int64
# 평균할부개월수      float64
# 구매브랜드종류        int64
# 내점일수           int64
# 수입상품_구매비율    float64
# 주말방문비율       float64
# 가을_구매건수      float64
# 겨울_구매건수      float64
# 봄_구매건수       float64
# 여름_구매건수      float64
# 아침_구매건수      float64
# 저녁_구매건수      float64
# 점심_구매건수      float64
# 주구매코너         object
# dtype: object

# %%
data.isnull().sum()
# Out:
# custid          0
# gender          0
# 총구매액            0
# 구매건수            0
# 평균구매가격          0
# 평균할부개월수         0
# 구매브랜드종류         0
# 내점일수            0
# 수입상품_구매비율       0
# 주말방문비율          0
# 가을_구매건수       945
# 겨울_구매건수       897
# 봄_구매건수        689
# 여름_구매건수      1022
# 아침_구매건수      1442
# 저녁_구매건수       967
# 점심_구매건수       145
# 주구매코너           0
# dtype: int64

# %%
data['주구매코너'].value_counts()
# Out:
# 일반식품        1306
# 화장품         1206
# 유니캐주얼        410
# 유아동복         383
# 스포츠          301
# 영캐주얼         246
# 캐릭터캐주얼       188
# 수입명품         136
# 섬유            96
# 트래디셔널캐주얼      91
# 니트단품          91
# 정장셔츠          90
# 엘레강스캐주얼       78
# 피혁A           75
# 장신구           68
# 피혁B           56
# 디자이너부띠끄       51
# 문화완구          38
# 조리욕실          28
# 가전            18
# 기타바이어         12
# 도자기크리스탈       11
# 침구수예           8
# 가구             7
# 타운모피           6
# Name: 주구매코너, dtype: int64

# %% [markdown]
# 유일한 ojbect 데이터인 주구매 코너에 대해서 데이터 정제
# -> 코너별로 구매건수를 구한다
# -> 비슷한 카테고리별로 묶는다(식품, 의류, 생필품, 가구 , 문화, 악세사리 , 화장품)

# %%
data1 = data.copy()

# %%
data1.head()
# Out:
#    custid  gender     총구매액  구매건수  평균구매가격  평균할부개월수  구매브랜드종류  내점일수  수입상품_구매비율  \
# 0      18       0   680100    15   45340      1.7        9    10       26.7
# 1      21       0   353450     9   39272      1.2        6     8       11.1
# 2      23       0  5671400    36  157539      2.8       22    16        5.6
# 3      26       0  1964000    28   70143      1.4       15    14       39.3
# 4      35       0   885000     5  177000      6.0        5     2        0.0
#
#    주말방문비율  가을_구매건수  겨울_구매건수  봄_구매건수  여름_구매건수  아침_구매건수  저녁_구매건수  점심_구매건수 주구매코너
# 0   100.0      NaN      9.0     6.0      NaN      NaN      6.0      9.0   화장품
# 1    37.5      NaN      5.0     4.0      NaN      3.0      NaN      6.0  영캐주얼
# 2    37.5      7.0     17.0    12.0      NaN     10.0     11.0     15.0   장신구
# 3    28.6      5.0      8.0    15.0      NaN      NaN     18.0     10.0   화장품
# 4   100.0      NaN      NaN     5.0      NaN      NaN      5.0      NaN   피혁A

# %%
data_sum = data1.groupby('주구매코너')['구매건수'].sum()

# %%
data_sum.head()
# Out:
# 주구매코너
# 가구          100
# 가전          315
# 기타바이어       149
# 니트단품       2542
# 도자기크리스탈     261
# Name: 구매건수, dtype: int64

# %%
data_sum = data_sum.reset_index()
data_sum.columns = ['주구매코너', '코너별구매건']

# %%
data_sum
# Out:
#        주구매코너  코너별구매건
# 0         가구     100
# 1         가전     315
# 2      기타바이어     149
# 3       니트단품    2542
# 4    도자기크리스탈     261
# 5    디자이너부띠끄    2219
# 6       문화완구     848
# 7         섬유    1627
# 8       수입명품    4846
# 9        스포츠   10664
# 10   엘레강스캐주얼    2242
# 11      영캐주얼    8285
# 12     유니캐주얼   10681
# 13      유아동복   14052
# 14      일반식품   76174
# 15       장신구    1165
# 16      정장셔츠    1259
# 17      조리욕실     607
# 18      침구수예      80
# 19    캐릭터캐주얼    5212
# 20      타운모피     148
# 21  트래디셔널캐주얼    1771
# 22       피혁A     880
# 23       피혁B     825
# 24       화장품   25740

# %%
data_sum.head(2)
# Out:
#   주구매코너  코너별구매건
# 0    가구     100
# 1    가전     315

# %%
data_merge = data1.merge(data_sum, how='left',on = '주구매코너')
data_merge
# Out:
#       custid  gender     총구매액  구매건수  평균구매가격  평균할부개월수  구매브랜드종류  내점일수  \
# 0         18       0   680100    15   45340      1.7        9    10
# 1         21       0   353450     9   39272      1.2        6     8
# 2         23       0  5671400    36  157539      2.8       22    16
# 3         26       0  1964000    28   70143      1.4       15    14
# 4         35       0   885000     5  177000      6.0        5     2
# ...      ...     ...      ...   ...     ...      ...      ...   ...
# 4995   49952       1  6666517    93   71683      1.8       27    39
# 4996   49954       0  3112100    17  183065      3.6       10    13
# 4997   49957       1  5852482    37  158175      2.6       14    21
# 4998   49975       1   654498    13   50346      2.5       10     7
# 4999   49993       1  2554723    32   79835      1.7        9    26
#
#       수입상품_구매비율  주말방문비율  가을_구매건수  겨울_구매건수  봄_구매건수  여름_구매건수  아침_구매건수  저녁_구매건수  \
# 0          26.7   100.0      NaN      9.0     6.0      NaN      NaN      6.0
# 1          11.1    37.5      NaN      5.0     4.0      NaN      3.0      NaN
# 2           5.6    37.5      7.0     17.0    12.0      NaN     10.0     11.0
# 3          39.3    28.6      5.0      8.0    15.0      NaN      NaN     18.0
# 4           0.0   100.0      NaN      NaN     5.0      NaN      NaN      5.0
# ...         ...     ...      ...      ...     ...      ...      ...      ...
# 4995       10.8    43.6     13.0     33.0    14.0     33.0      8.0     41.0
# 4996       29.4    38.5      4.0      6.0     6.0      1.0      3.0      NaN
# 4997       40.5    19.0     12.0      6.0     6.0     13.0     16.0      NaN
# 4998        7.7    14.3      6.0      4.0     2.0      1.0      NaN      2.0
# 4999       21.9    34.6      6.0      5.0    10.0     11.0      8.0      5.0
#
#       점심_구매건수    주구매코너  코너별구매건
# 0         9.0      화장품   25740
# 1         6.0     영캐주얼    8285
# 2        15.0      장신구    1165
# 3        10.0      화장품   25740
# 4         NaN      피혁A     880
# ...       ...      ...     ...
# 4995     44.0     일반식품   76174
# 4996     14.0  디자이너부띠끄    2219
# 4997     21.0      화장품   25740
# 4998     11.0      피혁A     880
# 4999     19.0     일반식품   76174
#
# [5000 rows x 19 columns]

# %%
features = []
f = data1.groupby('custid')['구매건수'].agg([('코너별구매건수','sum')]).reset_index()
features.append(f)
f
# Out:
#       custid  코너별구매건수
# 0         18       15
# 1         21        9
# 2         23       36
# 3         26       28
# 4         35        5
# ...      ...      ...
# 4995   49952       93
# 4996   49954       17
# 4997   49957       37
# 4998   49975       13
# 4999   49993       32
#
# [5000 rows x 2 columns]

# %% [markdown]
# 코너별로 구매건수 확인하여 파생변수 생성

# %%
f = data1.groupby('custid')['총구매액'].agg([('코너별구매액', 'sum')]).reset_index()
features.append(f)
f
# Out:
#       custid   코너별구매액
# 0         18   680100
# 1         21   353450
# 2         23  5671400
# 3         26  1964000
# 4         35   885000
# ...      ...      ...
# 4995   49952  6666517
# 4996   49954  3112100
# 4997   49957  5852482
# 4998   49975   654498
# 4999   49993  2554723
#
# [5000 rows x 2 columns]

# %% [markdown]
# 코너별로 구매액 확인하여 파생변수 생성

# %%
f = data1.groupby('custid')['총구매액'].agg([('평균구매가격', 'mean')]).reset_index()
features.append(f)
f
# Out:
#       custid   평균구매가격
# 0         18   680100
# 1         21   353450
# 2         23  5671400
# 3         26  1964000
# 4         35   885000
# ...      ...      ...
# 4995   49952  6666517
# 4996   49954  3112100
# 4997   49957  5852482
# 4998   49975   654498
# 4999   49993  2554723
#
# [5000 rows x 2 columns]

# %%
features
# Out:
# [      custid  코너별구매건수
#  0         18       15
#  1         21        9
#  2         23       36
#  3         26       28
#  4         35        5
#  ...      ...      ...
#  4995   49952       93
#  4996   49954       17
#  4997   49957       37
#  4998   49975       13
#  4999   49993       32
#
#  [5000 rows x 2 columns],
#        custid   코너별구매액
#  0         18   680100
#  1         21   353450
#  2         23  5671400
#  3         26  1964000
#  4         35   885000
#  ...      ...      ...
#  4995   49952  6666517
#  4996   49954  3112100
#  4997   49957  5852482
#  4998   49975   654498
#  4999   49993  2554723
#
#  [5000 rows x 2 columns],
#        custid   평균구매가격
#  0         18   680100
#  1         21   353450
#  2         23  5671400
#  3         26  1964000
#  4         35   885000
#  ...      ...      ...
#  4995   49952  6666517
#  4996   49954  3112100
#  4997   49957  5852482
#  4998   49975   654498
#  4999   49993  2554723
#
#  [5000 rows x 2 columns]]

# %%
data_sum['주구매코너']
# Out:
# 0           가구
# 1           가전
# 2        기타바이어
# 3         니트단품
# 4      도자기크리스탈
# 5      디자이너부띠끄
# 6         문화완구
# 7           섬유
# 8         수입명품
# 9          스포츠
# 10     엘레강스캐주얼
# 11        영캐주얼
# 12       유니캐주얼
# 13        유아동복
# 14        일반식품
# 15         장신구
# 16        정장셔츠
# 17        조리욕실
# 18        침구수예
# 19      캐릭터캐주얼
# 20        타운모피
# 21    트래디셔널캐주얼
# 22         피혁A
# 23         피혁B
# 24         화장품
# Name: 주구매코너, dtype: object

# %%
data_train = pd.DataFrame({'custid' : data1.custid.unique()})
data_train
# Out:
#       custid
# 0         18
# 1         21
# 2         23
# 3         26
# 4         35
# ...      ...
# 4995   49952
# 4996   49954
# 4997   49957
# 4998   49975
# 4999   49993
#
# [5000 rows x 1 columns]

# %%
data1.loc[(data1['주구매코너'] == '수입명품'),'코너묶음'] ='명품'

# %%
data1.loc[(data1['주구매코너'] == '기타바이어') |
         (data1['주구매코너'] == '문화완구'),'코너묶음'] = '기타'

# %%
data1.loc[(data1['주구매코너'] == '영캐주얼') |
         (data1['주구매코너'] == '유니캐주얼')|
         (data1['주구매코너'] == '유아동복')|
         (data1['주구매코너'] == '캐릭터캐주얼')|
         (data1['주구매코너'] == '트래디셔널캐주얼'),'코너묶음'] ='아동'

# %%
data1.loc[(data1['주구매코너'] == '정장셔츠')|
         (data1['주구매코너'] == '타운모피')|
         (data1['주구매코너'] == '디자이너부띠끄')|
         (data1['주구매코너'] == '니트단품')|
         (data1['주구매코너'] == '엘레강스캐주얼')|
         (data1['주구매코너'] == '스포츠'),'코너묶음'] = '성인'

# %%
data1.loc[(data1['주구매코너'] == '가구')|
         (data1['주구매코너'] == '가전')|
         (data1['주구매코너'] == '도자기크리스탈')|
         (data1['주구매코너'] == '조리욕실')|
         (data1['주구매코너'] == '침구수예'), '코너묶음'] = '집'

# %%
data1.loc[(data1['주구매코너'] == '피혁A')|
           (data1['주구매코너'] == '피혁B')|
           (data1['주구매코너'] == '섬유'), '코너묶음'] ='의류'

# %%
data1.loc[(data1['주구매코너'] == '장신구')|
         (data1['주구매코너'] == '화장품'), '코너묶음'] = '악세사리'

# %%
data1.loc[(data1['주구매코너'] == '일반식품'), '코너묶음'] ='식품'

# %%
data1.head(20)
# Out:
#     custid  gender     총구매액  구매건수  평균구매가격  평균할부개월수  구매브랜드종류  내점일수  수입상품_구매비율  \
# 0       18       0   680100    15   45340      1.7        9    10       26.7
# 1       21       0   353450     9   39272      1.2        6     8       11.1
# 2       23       0  5671400    36  157539      2.8       22    16        5.6
# 3       26       0  1964000    28   70143      1.4       15    14       39.3
# 4       35       0   885000     5  177000      6.0        5     2        0.0
# 5       50       0  3580200    36   99450      2.4       27    20        0.0
# 6       69       0   816300    14   58307      1.7       10    10        7.1
# 7       82       0   752200     5  150440      2.6        5     3       60.0
# 8       92       0  1145400    13   88108      1.9        7     9       23.1
# 9      100       0   442160    16   27635      1.0       10     6       25.0
# 10     102       0   590000     5  118000      3.0        4     4       20.0
# 11     103       0   836600    15   55773      2.1       13    12       26.7
# 12     126       0  1892400    41   46156      1.6       26    28       19.5
# 13     148       0  2897110    24  120713      1.5       18    15        0.0
# 14     154       0   285000     4   71250      2.0        3     2       50.0
# 15     161       0  2215000    28   79107      1.9       21    15        0.0
# 16     174       0   433600     8   54200      2.6        5     4        0.0
# 17     175       0  6466400    66   97976      2.0       38    33       10.6
# 18     186       0  2305740    32   72054      2.0       19    16       15.6
# 19     196       0  3581560    36   99488      1.7       21    23       41.7
#
#     주말방문비율  가을_구매건수  겨울_구매건수  봄_구매건수  여름_구매건수  아침_구매건수  저녁_구매건수  점심_구매건수  \
# 0    100.0      NaN      9.0     6.0      NaN      NaN      6.0      9.0
# 1     37.5      NaN      5.0     4.0      NaN      3.0      NaN      6.0
# 2     37.5      7.0     17.0    12.0      NaN     10.0     11.0     15.0
# 3     28.6      5.0      8.0    15.0      NaN      NaN     18.0     10.0
# 4    100.0      NaN      NaN     5.0      NaN      NaN      5.0      NaN
# 5     50.0      7.0      7.0     8.0     14.0      1.0     11.0     24.0
# 6     40.0      4.0      4.0     6.0      NaN      NaN      3.0     11.0
# 7    100.0      NaN      NaN     5.0      NaN      NaN      NaN      5.0
# 8     22.2      1.0      NaN     2.0     10.0      1.0      8.0      4.0
# 9     33.3      NaN      5.0    11.0      NaN      NaN      3.0     13.0
# 10   100.0      3.0      1.0     NaN      1.0      NaN      NaN      5.0
# 11    41.7      4.0      3.0     4.0      4.0      NaN      8.0      7.0
# 12    39.3     10.0      7.0     3.0     21.0      4.0     14.0     23.0
# 13    26.7      6.0      6.0     8.0      4.0      5.0      1.0     18.0
# 14     0.0      NaN      NaN     4.0      NaN      NaN      4.0      NaN
# 15    40.0      2.0      6.0     8.0     12.0      NaN     12.0     16.0
# 16    50.0      NaN      5.0     NaN      3.0      NaN      5.0      3.0
# 17    57.6     17.0     26.0    16.0      7.0      7.0     11.0     48.0
# 18    68.8     11.0      4.0     2.0     15.0      NaN     17.0     15.0
# 19    43.5      9.0     26.0     NaN      1.0      6.0     22.0      8.0
#
#     주구매코너  코너묶음
# 0     화장품  악세사리
# 1    영캐주얼    아동
# 2     장신구  악세사리
# 3     화장품  악세사리
# 4     피혁A    의류
# 5    영캐주얼    아동
# 6   유니캐주얼    아동
# 7     화장품  악세사리
# 8     화장품  악세사리
# 9     화장품  악세사리
# 10    피혁A    의류
# 11  유니캐주얼    아동
# 12    화장품  악세사리
# 13  유니캐주얼    아동
# 14    화장품  악세사리
# 15     섬유    의류
# 16   영캐주얼    아동
# 17    화장품  악세사리
# 18    화장품  악세사리
# 19   니트단품    성인

# %%
data_train
# Out:
#       custid
# 0         18
# 1         21
# 2         23
# 3         26
# 4         35
# ...      ...
# 4995   49952
# 4996   49954
# 4997   49957
# 4998   49975
# 4999   49993
#
# [5000 rows x 1 columns]

# %%
for f in features:
    data_train = pd.merge(data_train, f, how='left')

# %%
data1.head()
# Out:
#    custid  gender     총구매액  구매건수  평균구매가격  평균할부개월수  구매브랜드종류  내점일수  수입상품_구매비율  \
# 0      18       0   680100    15   45340      1.7        9    10       26.7
# 1      21       0   353450     9   39272      1.2        6     8       11.1
# 2      23       0  5671400    36  157539      2.8       22    16        5.6
# 3      26       0  1964000    28   70143      1.4       15    14       39.3
# 4      35       0   885000     5  177000      6.0        5     2        0.0
#
#    주말방문비율  가을_구매건수  겨울_구매건수  봄_구매건수  여름_구매건수  아침_구매건수  저녁_구매건수  점심_구매건수 주구매코너  \
# 0   100.0      NaN      9.0     6.0      NaN      NaN      6.0      9.0   화장품
# 1    37.5      NaN      5.0     4.0      NaN      3.0      NaN      6.0  영캐주얼
# 2    37.5      7.0     17.0    12.0      NaN     10.0     11.0     15.0   장신구
# 3    28.6      5.0      8.0    15.0      NaN      NaN     18.0     10.0   화장품
# 4   100.0      NaN      NaN     5.0      NaN      NaN      5.0      NaN   피혁A
#
#    코너묶음
# 0  악세사리
# 1    아동
# 2  악세사리
# 3  악세사리
# 4    의류

# %%
data1_drop = data1.dropna(subset=['가을_구매건수','겨울_구매건수','봄_구매건수','여름_구매건수','아침_구매건수','저녁_구매건수','점심_구매건수' ])
data1_drop.shape
# Out:
# (2235, 19)

# %%
data1_drop.isnull().sum()
# Out:
# custid       0
# gender       0
# 총구매액         0
# 구매건수         0
# 평균구매가격       0
# 평균할부개월수      0
# 구매브랜드종류      0
# 내점일수         0
# 수입상품_구매비율    0
# 주말방문비율       0
# 가을_구매건수      0
# 겨울_구매건수      0
# 봄_구매건수       0
# 여름_구매건수      0
# 아침_구매건수      0
# 저녁_구매건수      0
# 점심_구매건수      0
# 주구매코너        0
# 코너묶음         0
# dtype: int64

# %%
con = ['가을_구매건수','겨울_구매건수','봄_구매건수','여름_구매건수','아침_구매건수','저녁_구매건수','점심_구매건수' ]

# %%
from sklearn.impute import SimpleImputer
imputer_con = SimpleImputer(strategy="most_frequent")  
imputer_con.fit(data1[con])
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
x = imputer_con.transform(data1[con])
x
# Out:
# array([[ 1.,  9.,  6., ...,  1.,  6.,  9.],
#        [ 1.,  5.,  4., ...,  3.,  1.,  6.],
#        [ 7., 17., 12., ..., 10., 11., 15.],
#        ...,
#        [12.,  6.,  6., ..., 16.,  1., 21.],
#        [ 6.,  4.,  2., ...,  1.,  2., 11.],
#        [ 6.,  5., 10., ...,  8.,  5., 19.]])

# %%
data1[con] = x
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   custid     5000 non-null   int64
#  1   gender     5000 non-null   int64
#  2   총구매액       5000 non-null   int64
#  3   구매건수       5000 non-null   int64
#  4   평균구매가격     5000 non-null   int64
#  5   평균할부개월수    5000 non-null   float64
#  6   구매브랜드종류    5000 non-null   int64
#  7   내점일수       5000 non-null   int64
#  8   수입상품_구매비율  5000 non-null   float64
#  9   주말방문비율     5000 non-null   float64
#  10  가을_구매건수    5000 non-null   float64
#  11  겨울_구매건수    5000 non-null   float64
#  12  봄_구매건수     5000 non-null   float64
#  13  여름_구매건수    5000 non-null   float64
#  14  아침_구매건수    5000 non-null   float64
#  15  저녁_구매건수    5000 non-null   float64
#  16  점심_구매건수    5000 non-null   float64
#  17  주구매코너      5000 non-null   object
#  18  코너묶음       5000 non-null   object
# dtypes: float64(10), int64(7), object(2)
# memory usage: 742.3+ KB

# %%
obj = ['주구매코너','코너묶음']

# %%
data1[obj] = data1[obj].apply(lambda x: x.astype('category').cat.codes)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   custid     5000 non-null   int64
#  1   gender     5000 non-null   int64
#  2   총구매액       5000 non-null   int64
#  3   구매건수       5000 non-null   int64
#  4   평균구매가격     5000 non-null   int64
#  5   평균할부개월수    5000 non-null   float64
#  6   구매브랜드종류    5000 non-null   int64
#  7   내점일수       5000 non-null   int64
#  8   수입상품_구매비율  5000 non-null   float64
#  9   주말방문비율     5000 non-null   float64
#  10  가을_구매건수    5000 non-null   float64
#  11  겨울_구매건수    5000 non-null   float64
#  12  봄_구매건수     5000 non-null   float64
#  13  여름_구매건수    5000 non-null   float64
#  14  아침_구매건수    5000 non-null   float64
#  15  저녁_구매건수    5000 non-null   float64
#  16  점심_구매건수    5000 non-null   float64
#  17  주구매코너      5000 non-null   int8
#  18  코너묶음       5000 non-null   int8
# dtypes: float64(10), int64(7), int8(2)
# memory usage: 674.0 KB

# %%
dt0 = data1.groupby(['주구매코너'])['구매건수'].agg(sum)   
df0 = dt0.to_frame().reset_index()
df0.columns = ['주구매코너', '코너별구매건']
#df0.head(3)
data1_ = pd.merge(data1, df0, on='주구매코너')
# dataP_.head()
print(data1_[(data1_['주구매코너']==1)].groupby(['gender'])['총구매액'].agg(sum))
print(data1_[(data1_['주구매코너']==1)].groupby(['gender'])['구매건수'].agg(sum))
data1_.head()
# Out:
# gender
# 0    31111117
# 1    29039091
# Name: 총구매액, dtype: int64
# gender
# 0    214
# 1    101
# Name: 구매건수, dtype: int64
#    custid  gender     총구매액  구매건수  평균구매가격  평균할부개월수  구매브랜드종류  내점일수  수입상품_구매비율  \
# 0      18       0   680100    15   45340      1.7        9    10       26.7
# 1      26       0  1964000    28   70143      1.4       15    14       39.3
# 2      82       0   752200     5  150440      2.6        5     3       60.0
# 3      92       0  1145400    13   88108      1.9        7     9       23.1
# 4     100       0   442160    16   27635      1.0       10     6       25.0
#
#    주말방문비율  가을_구매건수  겨울_구매건수  봄_구매건수  여름_구매건수  아침_구매건수  저녁_구매건수  점심_구매건수  \
# 0   100.0      1.0      9.0     6.0      1.0      1.0      6.0      9.0
# 1    28.6      5.0      8.0    15.0      1.0      1.0     18.0     10.0
# 2   100.0      1.0      1.0     5.0      1.0      1.0      1.0      5.0
# 3    22.2      1.0      1.0     2.0     10.0      1.0      8.0      4.0
# 4    33.3      1.0      5.0    11.0      1.0      1.0      3.0     13.0
#
#    주구매코너  코너묶음  코너별구매건
# 0     24     5   25740
# 1     24     5   25740
# 2     24     5   25740
# 3     24     5   25740
# 4     24     5   25740

# %%
def createFeatures(df_p):
    df_p['아침구매액'] = np.round(df_p['총구매액']*(df_p['아침_구매건수'] /df_p['구매건수'] ), 3)
    df_p['점심구매액'] = np.round(df_p['총구매액']*(df_p['점심_구매건수'] /df_p['구매건수'] ), 3)
    df_p['저녁구매액'] = np.round(df_p['총구매액']*(df_p['저녁_구매건수'] /df_p['구매건수'] ), 3)  
    df_p['봄구매액']   = np.round(df_p['총구매액']*(df_p['봄_구매건수'] /df_p['구매건수'] ), 3) 
    df_p['여름구매액'] = np.round(df_p['총구매액']*(df_p['여름_구매건수'] /df_p['구매건수'] ), 3) 
    df_p['가을구매액'] = np.round(df_p['총구매액']*(df_p['가을_구매건수'] /df_p['구매건수'] ), 3)  
    df_p['겨울구매액'] = np.round(df_p['총구매액']*(df_p['겨울_구매건수'] /df_p['구매건수'] ), 3)  
    df_p['내점구매율'] = np.round(df_p['구매건수'] /df_p['내점일수'], 3)

def dropFeatures(df_p):
    drop_cols = ['아침_구매건수', '점심_구매건수', '저녁_구매건수', '총구매액', '구매건수',
         '봄_구매건수', '여름_구매건수', '가을_구매건수', '겨울_구매건수', '내점일수'] 
    
    return df_p.drop(drop_cols, axis=1)

createFeatures(data1_)
dataPP = dropFeatures(data1_) 
dataPP[(dataPP['주구매코너']==2)].head()
# Out:
#       custid  gender  평균구매가격  평균할부개월수  구매브랜드종류  수입상품_구매비율  주말방문비율  주구매코너  \
# 4123     363       0   90960      3.0        4       20.0    25.0      2
# 4124    4822       0  248049      2.3       10       10.5    33.3      2
# 4125   11617       1  124767      3.8        8       25.0    62.5      2
# 4126   12979       0   79250      1.7       10        0.0    33.3      2
# 4127   16414       0   31625      1.0        6       12.5    14.3      2
#
#       코너묶음  코너별구매건       아침구매액        점심구매액       저녁구매액        봄구매액  \
# 4123     0     149   90960.000    90960.000  363840.000  454800.000
# 4124     0     149  992196.632  3224639.053  496098.316  744147.474
# 4125     0     149  124766.667   499066.667  873366.667  249533.333
# 4126     0     149  554750.000   396250.000   79250.000  158500.000
# 4127     0     149   63250.000   189750.000   31625.000   94875.000
#
#            여름구매액        가을구매액        겨울구매액  내점구매율
# 4123   90960.000    90960.000    90960.000  1.250
# 4124  992196.632  1736344.105  1240245.789  1.583
# 4125  499066.667   748600.000   124766.667  1.500
# 4126   79250.000   792500.000    79250.000  4.000
# 4127  158125.000    31625.000    31625.000  1.143

# %%
dataPP['내점구매율']
# Out:
# 0       1.500
# 1       2.000
# 2       1.667
# 3       1.444
# 4       2.667
#         ...
# 4995    1.917
# 4996    1.850
# 4997    1.571
# 4998    2.449
# 4999    1.308
# Name: 내점구매율, Length: 5000, dtype: float64

# %%
dfX = dataPP.drop(['custid','gender'], axis=1)

# %%
dfy = dataPP['gender']

# %% [markdown]
# dataPP를 사용하여 기본학습, 엔지니어링 후 학습

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    dfX, dfy, random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(max_depth=2).fit(X_train, y_train)
pred_tree = tree.predict(X_test)

# %%
X_train_fs= X_train.values

# %%
y_train_fs = y_train.values

# %%
from sklearn.model_selection import KFold
from sklearn import tree
from sklearn.metrics import accuracy_score

# K-Fold교차 검증
kf = KFold(n_splits=10, shuffle=True)
# 모델의 정밀도를 보존하기 위한 준비
scores = []
# 데이터를 셔플하고, 훈련데이터와 테스트 데이터를 분활
for train_id, test_id in kf.split(X_train_fs):
    # 훈련 데이터를 사용한 모델을 작성
    x = X_train_fs[train_id]
    y = y_train_fs[train_id]
    clf = tree.DecisionTreeClassifier()
    clf.fit(x,y)
    # 테스트 데이터에 모델을 적용
    pred_y = clf.predict(X_train_fs[test_id])
    # 모델의 정밀도를 계산하고 보존
    score = accuracy_score(y_train_fs[test_id], pred_y)
    scores.append(score)

# 모델의 평균정밀도, 표준편차를 확인
scores = np.array(scores)
print(scores.mean(), scores.std())
# Out:
# 0.5874666666666666 0.026346072867802425

# %%
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score

# 재현률, 적합률의 확인
#print(confusion_matrix(Y[test_id], pred_y))
print(recall_score(y_train_fs[test_id], pred_y))
print(precision_score(y_train_fs[test_id], pred_y))
# Out:
# 0.3153153153153153
# 0.3017241379310345

# %%
from sklearn.model_selection import GridSearchCV

# 패러메터의 범위설정
params = {
    'criterion': ['entropy'],    
    'max_depth': [2, 4, 6, 8, 10],
    'min_samples_leaf': [10, 20, 30, 40, 50],
}

# 그리드 서치의 실행조건을 설정
clf_gs = GridSearchCV(tree.DecisionTreeClassifier(), params, 
                      cv=KFold(n_splits=10, shuffle=True), scoring='accuracy')

# 그리드 서치 실행
clf_gs.fit(X_train_fs, y_train_fs)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=True),
#              estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['entropy'],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'min_samples_leaf': [10, 20, 30, 40, 50]},
#              scoring='accuracy')

# %%
print(clf_gs.best_score_)
print(clf_gs.best_params_)
# Out:
# 0.7069333333333333
# {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10}

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %%
fpr, tpr, _ = roc_curve(y_train_fs[test_id], clf_gs.predict_proba(X_train_fs[test_id])[:,1])
auc(fpr, tpr)
# Out:
# 0.5939803439803439

# %%
from xgboost import XGBClassifier
import xgboost as xgb
from xgboost import plot_importance
#import pan
import numpy as np

# %%
X_train_fs
# Out:
# array([[8.49310000e+04, 2.50000000e+00, 8.00000000e+00, ...,
#         6.79446154e+05, 4.24653846e+05, 2.16700000e+00],
#        [2.27900000e+04, 2.30000000e+00, 1.10000000e+01, ...,
#         1.13950000e+05, 2.50690000e+05, 1.53800000e+00],
#        [1.15436000e+05, 2.50000000e+00, 3.00000000e+00, ...,
#         2.30872000e+05, 1.15436000e+05, 1.33300000e+00],
#        ...,
#        [8.81860000e+04, 1.60000000e+00, 2.30000000e+01, ...,
#         3.52744000e+05, 2.64558000e+05, 2.05900000e+00],
#        [2.91950000e+04, 1.00000000e+00, 5.00000000e+00, ...,
#         2.91953330e+04, 2.91953330e+04, 1.20000000e+00],
#        [4.44500000e+04, 1.70000000e+00, 3.00000000e+00, ...,
#         2.22250000e+05, 4.44500000e+04, 3.00000000e+00]])

# %%
X_test_fs=X_test.values

# %%
dtrain = xgb.DMatrix(data=X_train_fs, label = y_train)
dtest = xgb.DMatrix(data=X_test_fs, label=y_test)

# %%
params = {'max_depth':3,
          'eta':0.1,
          'objective':'binary:logistic',
          'eval_metric':'logloss',
          'early_stoppings':100,
          'learning_rate' : 0.01,
# [374]	train-logloss:0.55629	eval-logloss:0.61624
# [375]	train-logloss:0.55619	eval-logloss:0.61622
# [376]	train-logloss:0.55612	eval-logloss:0.61621
# [377]	train-logloss:0.55602	eval-logloss:0.61623
# [378]	train-logloss:0.55595	eval-logloss:0.61622
# [379]	train-logloss:0.55591	eval-logloss:0.61625
# [380]	train-logloss:0.55584	eval-logloss:0.61626
# [381]	train-logloss:0.55575	eval-logloss:0.61626
# [382]	train-logloss:0.55563	eval-logloss:0.61620
# [383]	train-logloss:0.55555	eval-logloss:0.61622
# [384]	train-logloss:0.55546	eval-logloss:0.61623
# [385]	train-logloss:0.55539	eval-logloss:0.61625
# [386]	train-logloss:0.55534	eval-logloss:0.61626
# [387]	train-logloss:0.55525	eval-logloss:0.61627
# [388]	train-logloss:0.55514	eval-logloss:0.61621
# [389]	train-logloss:0.55506	eval-logloss:0.61619
# [390]	train-logloss:0.55497	eval-logloss:0.61622
# [391]	train-logloss:0.55493	eval-logloss:0.61625
# [392]	train-logloss:0.55485	eval-logloss:0.61627
# [393]	train-logloss:0.55477	eval-logloss:0.61629
# [394]	train-logloss:0.55469	eval-logloss:0.61628
# [395]	train-logloss:0.55461	eval-logloss:0.61630
# [396]	train-logloss:0.55451	eval-logloss:0.61621
# [397]	train-logloss:0.55447	eval-logloss:0.61622
# [398]	train-logloss:0.55440	eval-logloss:0.61624
# [399]	train-logloss:0.55433	eval-logloss:0.61627

# %%
estimator = XGBClassifier(
    objective= 'binary:logistic',
     eval_metric = "logloss",
    nthread=4,
    seed=42)
parameters = {
    'max_depth': range (2, 10, 1),
    'n_estimators': range(60, 220, 40),
    'learning_rate': [0.1, 0.01, 0.05]
}
grid_search = GridSearchCV(
estimator=estimator,
param_grid=parameters,
scoring = 'roc_auc',
n_jobs = 10,
cv = 10,
verbose=True
)

# %%
grid_search.fit(X_train_fs,y_train)
# Out:
# Fitting 10 folds for each of 96 candidates, totalling 960 fits
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=10)]: Done 180 tasks      | elapsed:   58.4s
# [Parallel(n_jobs=10)]: Done 430 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=10)]: Done 780 tasks      | elapsed:  5.0min
# [03:51:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [Parallel(n_jobs=10)]: Done 960 out of 960 | elapsed:  6.4min finished
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# GridSearchCV(cv=10,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, gamma=None,
#                                      gpu_id=None, importance_type='gain',
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None, nthread=4,
#                                      num_parallel_tree=None, random_state=None,
#                                      reg_alpha=None, reg_lambda=None,
#                                      scale_pos_weight=None, seed=42,
#                                      subsample=None, tree_method=None,
#                                      validate_parameters=None, verbosity=None),
#              n_jobs=10,
#              param_grid={'learning_rate': [0.1, 0.01, 0.05],
#                          'max_depth': range(2, 10),
#                          'n_estimators': range(60, 220, 40)},
#              scoring='roc_auc', verbose=True)

# %%
print(grid_search.best_score_)
print(grid_search.best_params_)
# Out:
# 0.6198736200399699
# {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 60}

# %%
fpr, tpr, _ = roc_curve(y_train_fs[test_id], grid_search.predict_proba(X_train_fs[test_id])[:,1])
auc(fpr, tpr)
# Out:
# 0.7027368277368278

# %% [markdown]
# 단순 표본으로의 예측률

# %% [markdown]
# -> 스케일링후의 예측률

# %%
dataPS = dataPP.copy()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(dataPS)
# Out:
# MinMaxScaler()

# %%
x = scaler.transform(dataPS)
dataPS = pd.DataFrame(x , columns = dataPS.columns)

# %%
dataPS.describe()
# Out:
#             custid       gender       평균구매가격      평균할부개월수      구매브랜드종류  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      0.503902     0.304200     0.175572     0.101740     0.123074
# std       0.287677     0.460114     0.079175     0.081173     0.109642
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.256483     0.000000     0.127769     0.044444     0.045113
# 50%       0.506793     0.000000     0.155188     0.088889     0.090226
# 75%       0.751701     1.000000     0.197174     0.133333     0.172932
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#          수입상품_구매비율       주말방문비율        주구매코너         코너묶음       코너별구매건  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      0.179899     0.385719     0.646208     0.537029     0.388932
# std       0.194836     0.245098     0.247343     0.184499     0.379004
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.050000     0.222000     0.500000     0.428571     0.107827
# 50%       0.125000     0.348500     0.583333     0.571429     0.337214
# 75%       0.250000     0.500000     0.958333     0.714286     1.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#              아침구매액        점심구매액        저녁구매액         봄구매액        여름구매액  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      0.033597     0.038559     0.040050     0.041252     0.034203
# std       0.047028     0.048270     0.047161     0.058861     0.043935
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.013322     0.015055     0.016474     0.009945     0.012267
# 50%       0.017891     0.024362     0.024283     0.021840     0.020205
# 75%       0.033346     0.043662     0.044095     0.049298     0.039604
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#              가을구매액        겨울구매액        내점구매율
# count  5000.000000  5000.000000  5000.000000
# mean      0.050831     0.060285     0.152520
# std       0.056867     0.057713     0.113202
# min       0.000000     0.000000     0.000000
# 25%       0.022553     0.029184     0.073682
# 50%       0.032283     0.040884     0.133273
# 75%       0.056197     0.068046     0.206591
# max       1.000000     1.000000     1.000000

# %%
dfX = dataPS.drop(['custid','gender'], axis=1) 
dfy = dataPS['gender']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    dfX, dfy, random_state=0)

# %%
X_train_fs= X_train.values

# %%
y_train_fs = y_train.values

# %%
tree = DecisionTreeClassifier(max_depth=2).fit(X_train, y_train)
#pred_tree = tree.predict(X_test_fs)

# %%
from sklearn.model_selection import KFold
from sklearn import tree
from sklearn.metrics import accuracy_score

# K-Fold교차 검증
kf = KFold(n_splits=10, shuffle=True)
# 모델의 정밀도를 보존하기 위한 준비
scores = []
# 데이터를 셔플하고, 훈련데이터와 테스트 데이터를 분활
for train_id, test_id in kf.split(X_train_fs):
    # 훈련 데이터를 사용한 모델을 작성
    x = X_train_fs[train_id]
    y = y_train_fs[train_id]
    clf = tree.DecisionTreeClassifier()
    clf.fit(x,y)
    # 테스트 데이터에 모델을 적용
    pred_y = clf.predict(X_train_fs[test_id])
    # 모델의 정밀도를 계산하고 보존
    score = accuracy_score(y_train_fs[test_id], pred_y)
    scores.append(score)

# 모델의 평균정밀도, 표준편차를 확인
scores = np.array(scores)
print(scores.mean(), scores.std())
# Out:
# 0.5888000000000001 0.021226398658274553

# %%
print(recall_score(y_train_fs[test_id], pred_y))
print(precision_score(y_train_fs[test_id], pred_y))
# Out:
# 0.3669724770642202
# 0.35398230088495575

# %%
params = {
    'criterion': ['entropy'],    
    'max_depth': [2, 4, 6, 8, 10],
    'min_samples_leaf': [10, 20, 30, 40, 50],
}

# 그리드 서치의 실행조건을 설정
clf_gs = GridSearchCV(tree.DecisionTreeClassifier(), params, 
                      cv=KFold(n_splits=10, shuffle=True), scoring='accuracy')

# 그리드 서치 실행
clf_gs.fit(X_train_fs, y_train_fs)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=True),
#              estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['entropy'],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'min_samples_leaf': [10, 20, 30, 40, 50]},
#              scoring='accuracy')

# %%
print(clf_gs.best_score_)
print(clf_gs.best_params_)
# Out:
# 0.7069333333333333
# {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10}

# %%
fpr, tpr, _ = roc_curve(y_train_fs[test_id], clf_gs.predict_proba(X_train_fs[test_id])[:,1])
auc(fpr, tpr)
# Out:
# 0.5700317307029041

# %%
dtrain = xgb.DMatrix(data=X_train_fs, label = y_train)
dtest = xgb.DMatrix(data=X_test_fs, label=y_test)

# %%
params = {'max_depth':3,
          'eta':0.1,
          'objective':'binary:logistic',
          'eval_metric':'logloss',
          'early_stoppings':100,
          'learning_rate' : 0.01,
          'n_estimators' : 100
         }

num_rounds = 400

# %%
# train 데이터 세트는 'train', evaluation(test) 데이터 세트는 'eval'로 명기
wlist = [(dtrain, 'train'),(dtest, 'eval')]
# 하이퍼 파라미터와 early stoppinig 파라미터를 train() 함수의 파라미터로 전달
xgb_model = xgb.train(params=params, dtrain=dtrain, num_boost_round=num_rounds, evals=wlist)
# Out:
# [10:44:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { early_stoppings, n_estimators } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-logloss:0.69113	eval-logloss:0.69319
# [1]	train-logloss:0.68915	eval-logloss:0.69322
# [2]	train-logloss:0.68721	eval-logloss:0.69326
# [3]	train-logloss:0.68531	eval-logloss:0.69330
# [4]	train-logloss:0.68344	eval-logloss:0.69333
# [5]	train-logloss:0.68161	eval-logloss:0.69337
# [6]	train-logloss:0.67982	eval-logloss:0.69341
# [7]	train-logloss:0.67806	eval-logloss:0.69344
# [8]	train-logloss:0.67634	eval-logloss:0.69348
# [9]	train-logloss:0.67464	eval-logloss:0.69351
# [10]	train-logloss:0.67297	eval-logloss:0.69355
# [11]	train-logloss:0.67134	eval-logloss:0.69358
# [12]	train-logloss:0.66974	eval-logloss:0.69362
# [13]	train-logloss:0.66817	eval-logloss:0.69365
# [14]	train-logloss:0.66663	eval-logloss:0.69368
# [15]	train-logloss:0.66511	eval-logloss:0.69372
# [16]	train-logloss:0.66363	eval-logloss:0.69375
# [17]	train-logloss:0.66217	eval-logloss:0.69378
# [18]	train-logloss:0.66073	eval-logloss:0.69357
# [19]	train-logloss:0.65933	eval-logloss:0.69360
# [20]	train-logloss:0.65795	eval-logloss:0.69338
# [21]	train-logloss:0.65659	eval-logloss:0.69341
# [22]	train-logloss:0.65526	eval-logloss:0.69320
# [23]	train-logloss:0.65396	eval-logloss:0.69322
# [24]	train-logloss:0.65267	eval-logloss:0.69315
# [25]	train-logloss:0.65141	eval-logloss:0.69317
# [26]	train-logloss:0.65018	eval-logloss:0.69309
# [27]	train-logloss:0.64896	eval-logloss:0.69311
# [28]	train-logloss:0.64777	eval-logloss:0.69290
# [29]	train-logloss:0.64660	eval-logloss:0.69292
# [30]	train-logloss:0.64545	eval-logloss:0.69284
# [31]	train-logloss:0.64431	eval-logloss:0.69286
# [32]	train-logloss:0.64319	eval-logloss:0.69272
# [33]	train-logloss:0.64210	eval-logloss:0.69263
# [34]	train-logloss:0.64102	eval-logloss:0.69265
# [35]	train-logloss:0.63996	eval-logloss:0.69244
# [36]	train-logloss:0.63893	eval-logloss:0.69230
# [37]	train-logloss:0.63790	eval-logloss:0.69231
# [38]	train-logloss:0.63690	eval-logloss:0.69222
# [39]	train-logloss:0.63591	eval-logloss:0.69208
# [40]	train-logloss:0.63494	eval-logloss:0.69093
# [41]	train-logloss:0.63399	eval-logloss:0.69094
# [42]	train-logloss:0.63306	eval-logloss:0.69085
# [370]	train-logloss:0.55662	eval-logloss:0.64173
# [371]	train-logloss:0.55653	eval-logloss:0.64207
# [372]	train-logloss:0.55644	eval-logloss:0.64134
# [373]	train-logloss:0.55640	eval-logloss:0.64135
# [374]	train-logloss:0.55629	eval-logloss:0.64138
# [375]	train-logloss:0.55619	eval-logloss:0.64112
# [376]	train-logloss:0.55612	eval-logloss:0.64100
# [377]	train-logloss:0.55602	eval-logloss:0.64100
# [378]	train-logloss:0.55595	eval-logloss:0.64086
# [379]	train-logloss:0.55591	eval-logloss:0.64088
# [380]	train-logloss:0.55584	eval-logloss:0.64062
# [381]	train-logloss:0.55575	eval-logloss:0.64050
# [382]	train-logloss:0.55563	eval-logloss:0.64036
# [383]	train-logloss:0.55555	eval-logloss:0.64037
# [384]	train-logloss:0.55546	eval-logloss:0.64086
# [385]	train-logloss:0.55539	eval-logloss:0.64060
# [386]	train-logloss:0.55534	eval-logloss:0.64061
# [387]	train-logloss:0.55525	eval-logloss:0.64062
# [388]	train-logloss:0.55514	eval-logloss:0.64048
# [389]	train-logloss:0.55506	eval-logloss:0.64036
# [390]	train-logloss:0.55497	eval-logloss:0.64036
# [391]	train-logloss:0.55493	eval-logloss:0.64037
# [392]	train-logloss:0.55485	eval-logloss:0.64037
# [393]	train-logloss:0.55477	eval-logloss:0.64012
# [394]	train-logloss:0.55469	eval-logloss:0.64045
# [395]	train-logloss:0.55461	eval-logloss:0.64045
# [396]	train-logloss:0.55451	eval-logloss:0.64027
# [397]	train-logloss:0.55447	eval-logloss:0.64029
# [398]	train-logloss:0.55440	eval-logloss:0.64003
# [399]	train-logloss:0.55433	eval-logloss:0.64032

# %%
estimator = XGBClassifier(
    objective= 'binary:logistic',
     eval_metric = "logloss",
    nthread=4,
    seed=42)
parameters = {
    'max_depth': range (2, 10, 1),
    'n_estimators': range(60, 220, 40),
    'learning_rate': [0.1, 0.01, 0.05]
}
grid_search = GridSearchCV(
estimator=estimator,
param_grid=parameters,
scoring = 'roc_auc',
n_jobs = 10,
cv = 10,
verbose=True
)

# %%
grid_search.fit(X_train_fs,y_train)
# Out:
# Fitting 10 folds for each of 96 candidates, totalling 960 fits
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=10)]: Done 180 tasks      | elapsed:   34.7s
# [Parallel(n_jobs=10)]: Done 430 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=10)]: Done 780 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=10)]: Done 960 out of 960 | elapsed:  3.9min finished
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# GridSearchCV(cv=10,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      eval_metric='logloss', gamma=None,
#                                      gpu_id=None, importance_type='gain',
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None, nthread=4,
#                                      num_parallel_tree=None, random_state=None,
#                                      reg_alpha=None, reg_lambda=None,
#                                      scale_pos_weight=None, seed=42,
#                                      subsample=None, tree_method=None,
#                                      validate_parameters=None, verbosity=None),
#              n_jobs=10,
#              param_grid={'learning_rate': [0.1, 0.01, 0.05],
#                          'max_depth': range(2, 10),
#                          'n_estimators': range(60, 220, 40)},
#              scoring='roc_auc', verbose=True)

# %%
print(grid_search.best_score_)
print(grid_search.best_params_)
# Out:
# 0.6198736200399699
# {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 60}

# %%
fpr, tpr, _ = roc_curve(y_train[test_id], grid_search.predict_proba(X_train_fs[test_id])[:,1])
auc(fpr, tpr)
# Out:
# 0.7129750982961993

# %% [markdown]
# 스케일링 후 예측률

# %% [markdown]
# -> 스케일링 + KBest 셀렉션 후 예측률

# %%
dataSS = dataPS.copy()

# %%
dataSS.head()
# Out:
#      custid  gender    평균구매가격   평균할부개월수   구매브랜드종류  수입상품_구매비율  주말방문비율  주구매코너  \
# 0  0.000000     0.0  0.118288  0.077778  0.060150      0.267   1.000    1.0
# 1  0.000160     0.0  0.143117  0.044444  0.105263      0.393   0.286    1.0
# 2  0.001281     0.0  0.223499  0.177778  0.030075      0.600   1.000    1.0
# 3  0.001481     0.0  0.161101  0.100000  0.045113      0.231   0.222    1.0
# 4  0.001641     0.0  0.100564  0.000000  0.067669      0.250   0.333    1.0
#
#        코너묶음    코너별구매건     아침구매액     점심구매액     저녁구매액      봄구매액     여름구매액  \
# 0  0.714286  0.337214  0.011695  0.015525  0.022815  0.015213  0.009767
# 1  0.714286  0.337214  0.012629  0.019533  0.062933  0.047305  0.010487
# 2  0.714286  0.337214  0.015652  0.020227  0.017890  0.034966  0.012817
# 3  0.714286  0.337214  0.013305  0.014765  0.040345  0.011270  0.034016
# 4  0.714286  0.337214  0.011029  0.014858  0.015155  0.016527  0.009253
#
#       가을구매액     겨울구매액     내점구매율
# 0  0.019271  0.041942  0.090909
# 1  0.031474  0.048938  0.181818
# 2  0.023471  0.030169  0.121273
# 3  0.020980  0.027321  0.080727
# 4  0.018564  0.029609  0.303091

# %%
from sklearn.feature_selection import SelectKBest

print(X_train_fs.shape)
X_train_ss = SelectKBest(k=5).fit_transform(X_train_fs, y_train_fs) # 5개를 선택해 fit, transform을 동시에 해야함.
X_train_ss.shape
# Out:
# (3750, 16)
# (3750, 5)

# %%
kf = KFold(n_splits=10, shuffle=True)
# 모델의 정밀도를 보존하기 위한 준비
scores = []
# 데이터를 셔플하고, 훈련데이터와 테스트 데이터를 분활
for train_id, test_id in kf.split(X_train_ss):
    # 훈련 데이터를 사용한 모델을 작성
    x = X_train_ss[train_id]
    y = y_train_fs[train_id]
    clf = tree.DecisionTreeClassifier()
    clf.fit(x,y)
    # 테스트 데이터에 모델을 적용
    pred_y = clf.predict(X_train_ss[test_id])
    # 모델의 정밀도를 계산하고 보존
    score = accuracy_score(y_train_fs[test_id], pred_y)
    scores.append(score)

# 모델의 평균정밀도, 표준편차를 확인
scores = np.array(scores)
print(scores.mean(), scores.std())
# Out:
# 0.6008 0.012510617712789232

# %%
params = {
    'criterion': ['entropy'],    
    'max_depth': [2, 4, 6, 8, 10],
    'min_samples_leaf': [10, 20, 30, 40, 50],
}

# 그리드 서치의 실행조건을 설정
clf_gs = GridSearchCV(tree.DecisionTreeClassifier(), params, 
                      cv=KFold(n_splits=10, shuffle=True), scoring='accuracy')

# 그리드 서치 실행
clf_gs.fit(X_train_ss, y_train_fs)
# 가장 높은 정밀도와 패러메터의 조합을 표시
print(clf_gs.best_score_)
print(clf_gs.best_params_)
# Out:
# 0.7088000000000001
# {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 50}

# %%
fpr, tpr, _ = roc_curve(y_train_fs[test_id], clf_gs.predict_proba(X_train_ss[test_id])[:,1])
auc(fpr, tpr)
# Out:
# 0.5695962248084019

# %%
dtrain = xgb.DMatrix(data=X_train_fs, label = y_train)
dtest = xgb.DMatrix(data=X_test_fs, label=y_test)

# %%
params = {'max_depth':3,
          'eta':0.1,
          'objective':'binary:logistic',
          'eval_metric':'logloss',
          'early_stoppings':100,
          'learning_rate' : 0.01,
          'n_estimators' : 100
         }

num_rounds = 400

# %%
estimator = XGBClassifier(
    objective= 'binary:logistic',
     eval_metric = "logloss",
    nthread=4,
    seed=42)
parameters = {
    'max_depth': range (2, 10, 1),
    'n_estimators': range(60, 220, 40),
    'learning_rate': [0.1, 0.01, 0.05]
}
grid_search = GridSearchCV(
estimator=estimator,
param_grid=parameters,
scoring = 'roc_auc',
n_jobs = 10,
cv = 10,
verbose=True
)

# %%
grid_search.fit(X_train_fs,y_train)
# Out:
# Fitting 10 folds for each of 96 candidates, totalling 960 fits
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=10)]: Done 180 tasks      | elapsed:   34.1s
# [Parallel(n_jobs=10)]: Done 430 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=10)]: Done 780 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=10)]: Done 960 out of 960 | elapsed:  3.9min finished
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# GridSearchCV(cv=10,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      eval_metric='logloss', gamma=None,
#                                      gpu_id=None, importance_type='gain',
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None, nthread=4,
#                                      num_parallel_tree=None, random_state=None,
#                                      reg_alpha=None, reg_lambda=None,
#                                      scale_pos_weight=None, seed=42,
#                                      subsample=None, tree_method=None,
#                                      validate_parameters=None, verbosity=None),
#              n_jobs=10,
#              param_grid={'learning_rate': [0.1, 0.01, 0.05],
#                          'max_depth': range(2, 10),
#                          'n_estimators': range(60, 220, 40)},
#              scoring='roc_auc', verbose=True)

# %%
print(grid_search.best_score_)
print(grid_search.best_params_)
# Out:
# 0.6198736200399699
# {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 60}

# %%
fpr, tpr, _ = roc_curve(y_train[test_id], grid_search.predict_proba(X_train_fs[test_id])[:,1])
auc(fpr, tpr)
# Out:
# 0.6886437908496732

# %% [markdown]
# KBest는 제외

# %% [markdown]
# RandomForest 셀렉트 진행

# %%
dataS = dataPS.copy()

# %%
from sklearn.feature_selection import SelectFromModel

from sklearn.ensemble import RandomForestClassifier

select = SelectFromModel(RandomForestClassifier(), threshold=None) # threshold=None 스스로 알아서 처리
# select 는 전처리기

# %%
X_train_fs = select.fit(X_train, y_train).transform(X_train)
# 변수의 중요도가 나온다.
print("X_train.shape: {}, X_train_fs.shape: {}".format(
    X_train.shape, X_train_fs.shape))
# Out:
# X_train.shape: (3750, 16), X_train_fs.shape: (3750, 11)

# %%
kf = KFold(n_splits=10, shuffle=True)
# 모델의 정밀도를 보존하기 위한 준비
scores = []
# 데이터를 셔플하고, 훈련데이터와 테스트 데이터를 분활
for train_id, test_id in kf.split(X_train_fs):
    # 훈련 데이터를 사용한 모델을 작성
    x = X_train_fs[train_id]
    y = y_train_fs[train_id]
    clf = tree.DecisionTreeClassifier()
    clf.fit(x,y)
    # 테스트 데이터에 모델을 적용
    pred_y = clf.predict(X_train_fs[test_id])
    # 모델의 정밀도를 계산하고 보존
    score = accuracy_score(y_train_fs[test_id], pred_y)
    scores.append(score)

# 모델의 평균정밀도, 표준편차를 확인
scores = np.array(scores)
print(scores.mean(), scores.std())
# Out:
# 0.5954666666666666 0.0264538171998758

# %%
print(recall_score(y_train_fs[test_id], pred_y))
print(precision_score(y_train_fs[test_id], pred_y))
# Out:
# 0.31
# 0.28440366972477066

# %%
params = {
    'criterion': ['entropy'],    
    'max_depth': [2, 4, 6, 8, 10],
    'min_samples_leaf': [10, 20, 30, 40, 50],
}

# 그리드 서치의 실행조건을 설정
clf_gs = GridSearchCV(tree.DecisionTreeClassifier(), params, 
                      cv=KFold(n_splits=10, shuffle=True), scoring='accuracy')

# 그리드 서치 실행
clf_gs.fit(X_train_fs, y_train_fs)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=True),
#              estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['entropy'],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'min_samples_leaf': [10, 20, 30, 40, 50]},
#              scoring='accuracy')

# %%
print(clf_gs.best_score_)
print(clf_gs.best_params_)
# Out:
# 0.7074666666666667
# {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10}

# %%
fpr, tpr, _ = roc_curve(y_train_fs[test_id], clf_gs.predict_proba(X_train_fs[test_id])[:,1])
auc(fpr, tpr)
# Out:
# 0.5893272727272727

# %%
#단순 스케일링 auc점수가 높다

# %%
#폴리 + 스케일링 + 셀렉션

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
dfX = dataPS.drop(['custid','gender'], axis=1) 
dfy = dataPS['gender']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    dfX, dfy, random_state=0)

# %%
poly = PolynomialFeatures(2)

# %%
X_train_fs = poly.fit_transform (X_train_fs)

# %%
from sklearn.feature_selection import SelectKBest

print(X_train_fs.shape)
X_train_new= SelectKBest(k=5).fit_transform(X_train_fs, y_train_fs)
X_train_new.shape
# Out:
# (3750, 153)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# (3750, 5)

# %%
y_train_fs = y_train.values

# %%
from sklearn.model_selection import KFold
from sklearn import tree
from sklearn.metrics import accuracy_score

kf = KFold(n_splits=10, shuffle=True)
# 모델의 정밀도를 보존하기 위한 준비
scores = []
# 데이터를 셔플하고, 훈련데이터와 테스트 데이터를 분활
for train_id, test_id in kf.split(X_train_new):
    # 훈련 데이터를 사용한 모델을 작성
    x = X_train_new[train_id]
    y = y_train_fs[train_id]
    clf = tree.DecisionTreeClassifier()
    clf.fit(x,y)
    # 테스트 데이터에 모델을 적용
    pred_y = clf.predict(X_train_new[test_id])
    # 모델의 정밀도를 계산하고 보존
    score = accuracy_score(y_train_fs[test_id], pred_y)
    scores.append(score)

# 모델의 평균정밀도, 표준편차를 확인
scores = np.array(scores)
print(scores.mean(), scores.std())
# Out:
# 0.5946666666666667 0.02804440922695446

# %%
params = {
    'criterion': ['entropy'],    
    'max_depth': [2, 4, 6, 8, 10],
    'min_samples_leaf': [10, 20, 30, 40, 50],
}

# 그리드 서치의 실행조건을 설정
clf_gs = GridSearchCV(tree.DecisionTreeClassifier(), params, 
                      cv=KFold(n_splits=10, shuffle=True), scoring='accuracy')

# 그리드 서치 실행
clf_gs.fit(X_train_new, y_train_fs)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=True),
#              estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['entropy'],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'min_samples_leaf': [10, 20, 30, 40, 50]},
#              scoring='accuracy')

# %%
print(clf_gs.best_score_)
print(clf_gs.best_params_)
# Out:
# 0.7069333333333333
# {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 40}

# %%
fpr, tpr, _ = roc_curve(y_train_fs[test_id], clf_gs.predict_proba(X_train_new[test_id])[:,1])
auc(fpr, tpr)
# Out:
# 0.5976153482402216

# %%
dtrain = xgb.DMatrix(data=X_train_fs, label = y_train)
dtest = xgb.DMatrix(data=X_test_fs, label=y_test)

# %%
params = {'max_depth':3,
          'eta':0.1,
          'objective':'binary:logistic',
          'eval_metric':'logloss',
          'early_stoppings':100,
          'learning_rate' : 0.01,
          'n_estimators' : 100
         }

num_rounds = 400

# %%
estimator = XGBClassifier(
    objective= 'binary:logistic',
     eval_metric = "logloss",
    nthread=4,
    seed=42)
parameters = {
    'max_depth': range (2, 10, 1),
    'n_estimators': range(60, 220, 40),
    'learning_rate': [0.1, 0.01, 0.05]
}
grid_search = GridSearchCV(
estimator=estimator,
param_grid=parameters,
scoring = 'roc_auc',
n_jobs = 10,
cv = 10,
verbose=True
)

# %%
grid_search.fit(X_train_fs,y_train)
# Out:
# Fitting 10 folds for each of 96 candidates, totalling 960 fits
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:   13.2s
# [Parallel(n_jobs=10)]: Done 180 tasks      | elapsed:   49.8s
# [Parallel(n_jobs=10)]: Done 430 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=10)]: Done 780 tasks      | elapsed:  4.7min
# [23:34:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [Parallel(n_jobs=10)]: Done 960 out of 960 | elapsed:  6.1min finished
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# GridSearchCV(cv=10,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, gamma=None,
#                                      gpu_id=None, importance_type='gain',
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None, nthread=4,
#                                      num_parallel_tree=None, random_state=None,
#                                      reg_alpha=None, reg_lambda=None,
#                                      scale_pos_weight=None, seed=42,
#                                      subsample=None, tree_method=None,
#                                      validate_parameters=None, verbosity=None),
#              n_jobs=10,
#              param_grid={'learning_rate': [0.1, 0.01, 0.05],
#                          'max_depth': range(2, 10),
#                          'n_estimators': range(60, 220, 40)},
#              scoring='roc_auc', verbose=True)

# %%
print(grid_search.best_score_)
print(grid_search.best_params_)
# Out:
# 0.6198736200399699
# {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 60}

# %%
fpr, tpr, _ = roc_curve(y_train_fs[test_id], grid_search.predict_proba(X_train_fs[test_id])[:,1])
auc(fpr, tpr)
# Out:
# 0.6886437908496732
