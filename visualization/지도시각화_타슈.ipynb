# %%
import pandas as pd
import requests
import pprint
import folium
from folium import plugins     
import json
import re

# %%
df = pd.read_csv('대전' + str(1) + '.csv', encoding='cp949')

# %%
result = df.loc[:,'행정구역':'2020년01월_총인구수']

# %%
result['위도']=0.0
result['경도']=0.0

# %%
for i in range(2,6):
    df = pd.read_csv('대전' + str(i) + '.csv', encoding='cp949')
    test = df.loc[:,'행정구역': '2020년01월_총인구수']
    result = pd.concat([result,test],ignore_index=True)

# %%
for i in range(0,len(result)):
    result['행정구역'][i]= result['행정구역'][i].split('(')[0]
# Out:
# <ipython-input-6-6227b94eb92b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['행정구역'][i]= result['행정구역'][i].split('(')[0]

# %%
for i in range(len(result)):
    URL = 'https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyA6csRsevZkCKr47-nDzZj23nK-MDIcEIM' \
    '&sensor=false&language=ko&address={}'.format(result['행정구역'][i])
    response = requests.get(URL)
    data = response.json()
    lat = data['results'][0]['geometry']['location']['lat']
    lng = data['results'][0]['geometry']['location']['lng']
    result['위도'][i]=float(lat)
    result['경도'][i]=float(lng)
    print(result['행정구역'][i])
# Out:
# <ipython-input-7-13738e250e55>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['위도'][i]=float(lat)
# <ipython-input-7-13738e250e55>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['경도'][i]=float(lng)
# 대전광역시 동구
# 대전광역시 동구 중앙동
# 대전광역시 동구 효동
# 대전광역시 동구 신인동
# 대전광역시 동구 판암1동
# 대전광역시 동구 판암2동
# 대전광역시 동구 용운동
# 대전광역시 동구 대동
# 대전광역시 동구 자양동
# 대전광역시 동구 가양1동
# 대전광역시 동구 가양2동
# 대전광역시 동구 용전동
# 대전광역시 동구 성남동
# 대전광역시 동구 홍도동
# 대전광역시 동구 삼성동
# 대전광역시 동구 대청동
# 대전광역시 동구 산내동
# 대전광역시 대덕구
# 대전광역시 대덕구 오정동
# 대전광역시 대덕구 대화동
# 대전광역시 대덕구 회덕동
# 대전광역시 대덕구 비래동
# 대전광역시 대덕구 송촌동
# 대전광역시 대덕구 중리동
# 대전광역시 대덕구 신탄진동
# 대전광역시 대덕구 석봉동
# ...

# %%
popu_heatmap_data=result[['위도','경도']].values[:len(result)].tolist()

# %%
from tasu_info import *

# %%
tasu_info = pd.read_csv('tasu_2019.csv',encoding='utf-8')

# %%
for i in range(0,len(tasu_info)):
    tasu_info['이동거리'][i] = tasu_info['이동거리'][i]/100
# Out:
# <ipython-input-16-17b8f9d2da0e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tasu_info['이동거리'][i] = tasu_info['이동거리'][i]/100

# %%
station_test = pd.DataFrame(station)

# %%
station_test
# Out:
#                        장소
# 0        1.무역전시관입구(택시승강장)
# 1               2.대전컨벤션센터
# 2                3.한밭수목원1
# 3     4.초원아파트(104동 버스정류장)
# 4       5.둔산대공원 입구(버스정류장)
# ..                    ...
# 257             258.천문대입구
# 258             259.대덕대학교
# 259       260.오정농수산물 도매시장
# 260  261.도로교통공단(건너편 라도무스)
# 261             262.반석 더샵
#
# [262 rows x 1 columns]

# %%
station_test['위치']=""

# %%
for i in range(len(station_test)):
    station_test['위치'][i] =station_test['장소'][i].split('.')[1]

# %%
station_test['번호']=""

# %%
for i in range(len(station_test)):
    station_test['번호'][i] =station_test['장소'][i].split('.')[0]

# %%
station_test = station_test.drop('장소',axis=1)

# %%
tasu_info = tasu_info.drop_duplicates(['대여스테이션'])

# %%
tasu_info = tasu_info.reset_index()

# %%
tasu_info = tasu_info.drop('index',axis=1)

# %%
for i in range(0,len(tasu_info)):
    for j in range(0,len(station_test)):
        if tasu_info['대여스테이션'][i]==int(station_test['번호'][j]):
            tasu_info['대여스테이션'][i] = station_test['위치'][j]
# Out:
# <ipython-input-31-784a69f7ac3a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tasu_info['대여스테이션'][i] = station_test['위치'][j]
# C:\Users\17\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
tasu_info = tasu_info.reset_index()

# %%
loca = pd.read_csv('tasu_addr.csv',encoding='cp949')

# %%
loca['장소']=''

# %%
for i in range(len(loca)):
    loca['장소'][i]=loca['station'][i].split('.')[1]

# %%
loca = loca.drop('station',axis=1)

# %%
tasu_info
# Out:
#      index          대여스테이션            대여일시     반납스테이션            반납일시  \
# 0        0        비래동 산림조합  20190101000002 185.000000  20190101011608
# 1        1         만년동주민센터  20190101000111  29.000000  20190101001505
# 2        2      유성온천역 3번출구  20190101000212  66.000000  20190101001046
# 3        3       회덕농협(건너편)  20190101050336 244.000000  20190101055330
# 4        4     용전네거리(하나은행)  20190101050540 143.000000  20190101052545
# ..     ...             ...             ...        ...             ...
# 256    256           대성삼거리  20190119145104 194.000000  20190119155000
# 257    257    구)대덕경찰서(문평동)  20190119185207 162.000000  20190119190836
# 258    258        과선교버스정류장  20190204192629 128.000000  20190204195217
# 259    259        판암역 4번출구  20190307085844 166.000000  20190307091239
# 260    260  무역전시관입구(택시승강장)  20190708203014   3.000000  20190708212314
#
#          이동거리  회원구분
# 0    0.000000     2
# 1    5.300000     2
# 2    5.400000     2
# 3   31.300000     2
# ...

# %%
center = [36.35073319387249, 127.3848401557223]  # 대전시청 좌표
m=folium.Map(location=center, zoom_start=10)

# %%
for i in range(0,len(location_data)-1):
    if location_data[i] ==['','']:
        continue
    folium.Marker(location_data[i],popup=tasu_info['대여스테이션'][i]).add_to(m)

# %%
m
#대전 타슈 위치
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
m.save("test1.html")

# %%
center = [36.35073319387249, 127.3848401557223]  # 대전시청 좌표
m=folium.Map(location=center, zoom_start=10)

# %%
for i in range(0,len(location_data)-1):
    if location_data[i] ==['','']:
        continue
    station_color = 'black'
    folium.Circle(location=location_data[i],radius=tasu_info['이동거리'][i],color=station_color
                   ,fill=True,fill_opacity=1,tooltip=tasu_lat.index[i+1],popup=tasu_info['대여스테이션'][i]).add_to(m)

# %%
m
#원의 크기 = 이용빈도
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
m.save("test2.html")

# %%
center = [36.35073319387249, 127.3848401557223]  # 대전시청 좌표
m=folium.Map(location=center, zoom_start=10)

# %%
plugins.MarkerCluster(location_data).add_to(m)

# %%
m
#타슈 밀집도 시각화
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
m.save("test3.html")
